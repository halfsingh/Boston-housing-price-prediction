# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense,Dropout
from keras.optimizers import Adam

# %%
X_train = pd.read_csv('HOUSING USING MLP/Train_data.csv')

# %%
X_train.head(n=30)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1          60       RL         65.0     8450   Pave   NaN      Reg
# 1    2          20       RL         80.0     9600   Pave   NaN      Reg
# 2    3          60       RL         68.0    11250   Pave   NaN      IR1
# 3    4          70       RL         60.0     9550   Pave   NaN      IR1
# 4    5          60       RL         84.0    14260   Pave   NaN      IR1
# 5    6          50       RL         85.0    14115   Pave   NaN      IR1
# 6    7          20       RL         75.0    10084   Pave   NaN      Reg
# 7    8          60       RL          NaN    10382   Pave   NaN      IR1
# 8    9          50       RM         51.0     6120   Pave   NaN      Reg
# 9   10         190       RL         50.0     7420   Pave   NaN      Reg
# 10  11          20       RL         70.0    11200   Pave   NaN      Reg
# 11  12          60       RL         85.0    11924   Pave   NaN      IR1
# ...

# %%
X_train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 81 columns):
# Id               1100 non-null int64
# MSSubClass       1100 non-null int64
# MSZoning         1100 non-null object
# LotFrontage      908 non-null float64
# LotArea          1100 non-null int64
# Street           1100 non-null object
# Alley            69 non-null object
# LotShape         1100 non-null object
# LandContour      1100 non-null object
# Utilities        1100 non-null object
# LotConfig        1100 non-null object
# LandSlope        1100 non-null object
# Neighborhood     1100 non-null object
# Condition1       1100 non-null object
# Condition2       1100 non-null object
# BldgType         1100 non-null object
# HouseStyle       1100 non-null object
# OverallQual      1100 non-null int64
# OverallCond      1100 non-null int64
# YearBuilt        1100 non-null int64
# YearRemodAdd     1100 non-null int64
# RoofStyle        1100 non-null object
# ...

# %%
X_train.SalePrice.unique()
# Out:
# array([208500, 181500, 223500, 140000, 250000, 143000, 307000, 200000,
#        129900, 118000, 129500, 345000, 144000, 279500, 157000, 132000,
#        149000,  90000, 159000, 139000, 325300, 139400, 230000, 154000,
#        256300, 134800, 306000, 207500,  68500,  40000, 149350, 179900,
#        165500, 277500, 309000, 145000, 153000, 109000,  82000, 160000,
#        170000, 130250, 141000, 319900, 239686, 249700, 113000, 127000,
#        177000, 114500, 110000, 385000, 130000, 180500, 172500, 196500,
#        438780, 124900, 158000, 101000, 202500, 219500, 317000, 180000,
#        226000,  80000, 225000, 244000, 185000, 144900, 107400,  91000,
#        135750, 136500, 193500, 153500, 245000, 126500, 168500, 260000,
#        174000, 164500,  85000, 123600, 109900,  98600, 163500, 133900,
#        204750, 214000,  94750,  83000, 128950, 205000, 178000, 118964,
#        198900, 169500, 100000, 115000, 190000, 136900, 383970, 217000,
# ...

# %%
col = X_train.columns
print(col)
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
X_train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 8        9          50       RM         51.0     6120   Pave   NaN      Reg
# 9       10         190       RL         50.0     7420   Pave   NaN      Reg
# 10      11          20       RL         70.0    11200   Pave   NaN      Reg
# ...

# %%
#X_train.fillna(0,inplace=True)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 81 columns):
# Id               1100 non-null int64
# MSSubClass       1100 non-null int64
# MSZoning         1100 non-null object
# LotFrontage      908 non-null float64
# LotArea          1100 non-null int64
# Street           1100 non-null object
# Alley            69 non-null object
# LotShape         1100 non-null object
# LandContour      1100 non-null object
# Utilities        1100 non-null object
# LotConfig        1100 non-null object
# LandSlope        1100 non-null object
# Neighborhood     1100 non-null object
# Condition1       1100 non-null object
# Condition2       1100 non-null object
# BldgType         1100 non-null object
# HouseStyle       1100 non-null object
# OverallQual      1100 non-null int64
# OverallCond      1100 non-null int64
# YearBuilt        1100 non-null int64
# YearRemodAdd     1100 non-null int64
# RoofStyle        1100 non-null object
# ...

# %%
cat_columns = ['MSZoning','Street','Alley','LotShape','LandContour','Utilities','LotConfig','LandSlope','Neighborhood','Condition1','Condition2','BldgType','HouseStyle','RoofStyle','RoofMatl','Exterior1st','Exterior2nd','MasVnrType','ExterQual','ExterCond','Foundation','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','Heating','HeatingQC','CentralAir','Electrical','KitchenQual','Functional','FireplaceQu','GarageType','GarageFinish','GarageQual','GarageCond','PavedDrive','PoolQC','Fence','MiscFeature','SaleType','SaleCondition']

# %%
cat_df = X_train.select_dtypes(include=['object']).copy()

# %%
cat_df.head()
# Out:
#   MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1  ... GarageType GarageFinish GarageQual GarageCond  \
# 0      CollgCr       Norm  ...     Attchd          RFn         TA         TA
# 1      Veenker      Feedr  ...     Attchd          RFn         TA         TA
# 2      CollgCr       Norm  ...     Attchd          RFn         TA         TA
# 3      Crawfor       Norm  ...     Detchd          Unf         TA         TA
# 4      NoRidge       Norm  ...     Attchd          RFn         TA         TA
#
# ...

# %%
num_df = X_train.select_dtypes(include=['int64','float64']).copy()

# %%
num_df
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# 5        6          50         85.0    14115            5            5
# 6        7          20         75.0    10084            8            5
# 7        8          60          NaN    10382            7            6
# 8        9          50         51.0     6120            7            5
# 9       10         190         50.0     7420            5            6
# 10      11          20         70.0    11200            5            5
# 11      12          60         85.0    11924            9            5
# ...

# %%
num_df.isnull()
# Out:
#          Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0     False       False        False    False        False        False
# 1     False       False        False    False        False        False
# 2     False       False        False    False        False        False
# 3     False       False        False    False        False        False
# 4     False       False        False    False        False        False
# 5     False       False        False    False        False        False
# 6     False       False        False    False        False        False
# 7     False       False         True    False        False        False
# 8     False       False        False    False        False        False
# 9     False       False        False    False        False        False
# 10    False       False        False    False        False        False
# 11    False       False        False    False        False        False
# ...

# %%
num_df = num_df.fillna(0)

# %%
print(num_df.isnull())
# Out:
#          Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0     False       False        False    False        False        False
# 1     False       False        False    False        False        False
# 2     False       False        False    False        False        False
# 3     False       False        False    False        False        False
# 4     False       False        False    False        False        False
# 5     False       False        False    False        False        False
# 6     False       False        False    False        False        False
# 7     False       False        False    False        False        False
# 8     False       False        False    False        False        False
# 9     False       False        False    False        False        False
# 10    False       False        False    False        False        False
# 11    False       False        False    False        False        False
# ...

# %%
cat_df= cat_df.fillna('null')

# %%
cat_df.isnull()
# Out:
#       MSZoning  Street  Alley  LotShape  LandContour  Utilities  LotConfig  \
# 0        False   False  False     False        False      False      False
# 1        False   False  False     False        False      False      False
# 2        False   False  False     False        False      False      False
# 3        False   False  False     False        False      False      False
# 4        False   False  False     False        False      False      False
# 5        False   False  False     False        False      False      False
# 6        False   False  False     False        False      False      False
# 7        False   False  False     False        False      False      False
# 8        False   False  False     False        False      False      False
# 9        False   False  False     False        False      False      False
# 10       False   False  False     False        False      False      False
# ...

# %%
cat_df = cat_df.apply(le.fit_transform)

# %%
cat_df
# Out:
#       MSZoning  Street  Alley  LotShape  LandContour  Utilities  LotConfig  \
# 0            3       1      2         3            3          0          4
# 1            3       1      2         3            3          0          2
# 2            3       1      2         0            3          0          4
# 3            3       1      2         0            3          0          0
# 4            3       1      2         0            3          0          2
# 5            3       1      2         0            3          0          4
# 6            3       1      2         3            3          0          4
# 7            3       1      2         0            3          0          0
# 8            4       1      2         3            3          0          4
# 9            3       1      2         3            3          0          0
# 10           3       1      2         3            3          0          4
# ...

# %%
X_train = pd.concat([cat_df,num_df],axis = 1)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 81 columns):
# MSZoning         1100 non-null int32
# Street           1100 non-null int32
# Alley            1100 non-null int32
# LotShape         1100 non-null int32
# LandContour      1100 non-null int32
# Utilities        1100 non-null int32
# LotConfig        1100 non-null int32
# LandSlope        1100 non-null int32
# Neighborhood     1100 non-null int32
# Condition1       1100 non-null int32
# Condition2       1100 non-null int32
# BldgType         1100 non-null int32
# HouseStyle       1100 non-null int32
# RoofStyle        1100 non-null int32
# RoofMatl         1100 non-null int32
# Exterior1st      1100 non-null int32
# Exterior2nd      1100 non-null int32
# MasVnrType       1100 non-null int32
# ExterQual        1100 non-null int32
# ExterCond        1100 non-null int32
# Foundation       1100 non-null int32
# BsmtQual         1100 non-null int32
# ...

# %%
X_train.SalePrice.unique()
# Out:
# array([208500, 181500, 223500, 140000, 250000, 143000, 307000, 200000,
#        129900, 118000, 129500, 345000, 144000, 279500, 157000, 132000,
#        149000,  90000, 159000, 139000, 325300, 139400, 230000, 154000,
#        256300, 134800, 306000, 207500,  68500,  40000, 149350, 179900,
#        165500, 277500, 309000, 145000, 153000, 109000,  82000, 160000,
#        170000, 130250, 141000, 319900, 239686, 249700, 113000, 127000,
#        177000, 114500, 110000, 385000, 130000, 180500, 172500, 196500,
#        438780, 124900, 158000, 101000, 202500, 219500, 317000, 180000,
#        226000,  80000, 225000, 244000, 185000, 144900, 107400,  91000,
#        135750, 136500, 193500, 153500, 245000, 126500, 168500, 260000,
#        174000, 164500,  85000, 123600, 109900,  98600, 163500, 133900,
#        204750, 214000,  94750,  83000, 128950, 205000, 178000, 118964,
#        198900, 169500, 100000, 115000, 190000, 136900, 383970, 217000,
# ...

# %% [markdown]
# # Only MinMax Scaler use is required
# # Then train model and use sigmoid in last function
# # Lots of parameters

# %%
#from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # Trying min max scaler with just saleprice

# %%
#scaler = MinMaxScaler()

# %%
'''temp_saleprice = X_train['SalePrice'].values.reshape(-1,1)
saleprice_rescaled = scaler.fit_transform(temp_saleprice)
X_train['SalePrice'] = saleprice_rescaled'''
# Out:
# "temp_saleprice = X_train['SalePrice'].values.reshape(-1,1)\nsaleprice_rescaled = scaler.fit_transform(temp_saleprice)\nX_train['SalePrice'] = saleprice_rescaled"

# %%
X,Y = X_train[[col for col in X_train.columns if col!= 'SalePrice']].values, X_train['SalePrice'].values

# %%
#from keras.callbacks import ModelCheckpoint

# %%
#checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
#checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
#callbacks_list = [checkpoint]

# %%
"""""model = Sequential()
model.add(Dense(64,activation='sigmoid',input_shape=(80,)))
#model.add(Dense(512,activation = 'sigmoid'))
#model.add(Dense(256,activation = 'sigmoid'))
model.add(Dense(128,activation = 'sigmoid'))
model.add(Dense(32,activation = 'sigmoid'))
model.add(Dense(1))"""""
# Out:
# '""model = Sequential()\nmodel.add(Dense(64,activation=\'sigmoid\',input_shape=(80,)))\n#model.add(Dense(512,activation = \'sigmoid\'))\n#model.add(Dense(256,activation = \'sigmoid\'))\nmodel.add(Dense(128,activation = \'sigmoid\'))\nmodel.add(Dense(32,activation = \'sigmoid\'))\nmodel.add(Dense(1))'

# %%
#model.summary()

# %%
#from sklearn.metrics import r2_score

# %%
#from keras import backend as K

#def coeff_determination(y_true, y_pred):
#    SS_res =  K.sum(K.square( y_true-y_pred ))
#    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
#    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %%
#model.compile(loss='mse', optimizer = 'adam', metrics = [coeff_determination])

# %%
#hist = model.fit(X,Y,batch_size=256,epochs=25,validation_split=0.2)

# %%
from sklearn import linear_model

# %%
model = linear_model.LinearRegression()

# %%
model.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
import matplotlib.pyplot as plt

# %%
#plt.figure(0)
#plt.plot(hist.history['loss'],'g')
#plt.plot(hist.history['val_loss'],'b')

# %%
#plt.figure(0)
#plt.plot(hist.history['coeff_determination'],'g')
#plt.plot(hist.history['val_coeff_determination'],'b')

# %%
X_test_df = pd.read_csv('HOUSING USING MLP/Test_Data.csv')

# %%
X_test_df.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1101          30       RL         60.0     8400   Pave   NaN      Reg
# 1  1102          20       RL         61.0     9758   Pave   NaN      IR1
# 2  1103          20       RL         70.0     7000   Pave   NaN      Reg
# 3  1104          20       RL         79.0     8910   Pave   NaN      Reg
# 4  1105         160       RM         24.0     2016   Pave   NaN      Reg
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 0         Bnk    AllPub  ...           0        0    NaN   NaN         NaN
# 1         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 2         Lvl    AllPub  ...           0        0    NaN  MnWw         NaN
# 3         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 4         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
cat_columns = ['MSZoning','Street','Alley','LotShape','LandContour','Utilities','LotConfig','LandSlope','Neighborhood','Condition1','Condition2','BldgType','HouseStyle','RoofStyle','RoofMatl','Exterior1st','Exterior2nd','MasVnrType','ExterQual','ExterCond','Foundation','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','Heating','HeatingQC','CentralAir','Electrical','KitchenQual','Functional','FireplaceQu','GarageType','GarageFinish','GarageQual','GarageCond','PavedDrive','PoolQC','Fence','MiscFeature','SaleType','SaleCondition']

# %%
cat_df1 = X_test_df.select_dtypes(include=['object']).copy()

# %%
num_df1 = X_test_df.select_dtypes(include=['int64','float64']).copy()

# %%
num_df1 = num_df1.fillna(0)

# %%
cat_df1= cat_df1.fillna('null')

# %%
cat_df1
# Out:
#     MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0         RL   Pave  null      Reg         Bnk    AllPub    Inside       Gtl
# 1         RL   Pave  null      IR1         Lvl    AllPub    Inside       Gtl
# 2         RL   Pave  null      Reg         Lvl    AllPub    Inside       Gtl
# 3         RL   Pave  null      Reg         Lvl    AllPub    Corner       Gtl
# 4         RM   Pave  null      Reg         Lvl    AllPub    Inside       Gtl
# 5         RL   Pave  null      IR1         Lvl    AllPub    Corner       Gtl
# 6         RL   Pave  null      IR1         Lvl    AllPub    Corner       Gtl
# 7         RL   Pave  null      IR3         HLS    AllPub   CulDSac       Gtl
# 8         RL   Pave  null      Reg         Lvl    AllPub    Inside       Gtl
# 9         RL   Pave  null      IR1         Lvl    AllPub    Inside       Gtl
# 10        RL   Pave  null      Reg         Lvl    AllPub    Inside       Gtl
# ...

# %%
cat_df1 = cat_df1.apply(le.fit_transform)

# %%
cat_df1
# Out:
#      MSZoning  Street  Alley  LotShape  LandContour  Utilities  LotConfig  \
# 0           3       1      2         3            0          0          4
# 1           3       1      2         0            3          0          4
# 2           3       1      2         3            3          0          4
# 3           3       1      2         3            3          0          0
# 4           4       1      2         3            3          0          4
# 5           3       1      2         0            3          0          0
# 6           3       1      2         0            3          0          0
# 7           3       1      2         2            1          0          1
# 8           3       1      2         3            3          0          4
# 9           3       1      2         0            3          0          4
# 10          3       1      2         3            3          0          4
# 11          3       1      2         3            3          0          4
# ...

# %%
X_test_df = pd.concat([cat_df1,num_df1],axis = 1)

# %%
X_test_df.head()
# Out:
#    MSZoning  Street  Alley  LotShape  LandContour  Utilities  LotConfig  \
# 0         3       1      2         3            0          0          4
# 1         3       1      2         0            3          0          4
# 2         3       1      2         3            3          0          4
# 3         3       1      2         3            3          0          0
# 4         4       1      2         3            3          0          4
#
#    LandSlope  Neighborhood  Condition1  ...  GarageArea  WoodDeckSF  \
# 0          0            17           2  ...         246           0
# 1          0            11           2  ...         280           0
# 2          0            11           2  ...         254           0
# 3          0            11           2  ...         539           0
# 4          0             1           2  ...         440           0
#
#    OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  \
# ...

# %%
#Y_test = model.predict(X_test_df)

# %%
Y_test = model.predict(X_test_df)

# %%
#Y_test = Y_test.reshape((-1,1))
#Y_test = scaler.inverse_transform(Y_test)

# %%
#Y_test = pd.DataFrame(Y_test)
#Y_test.to_csv('Y_test(housing_prices)',index = True)

# %%
for i in range(Y_test.shape[0]):
    Y_test[i] = int(Y_test[i])

print(Y_test)
# Out:
# [ 84473. 163124. 177110. 210943. 155417. 382020. 266964. 302588. 205604.
#  347220. 228685. 254519. 166899. 183885. 169529. 362163. 252990. 185503.
#  168959. 172457. 168256. 280488. 116212. 145014. 220128. 168817. 250555.
#  300743. 274898. 177672. 191587. 163199. 202039. 294212. 221652. 149961.
#  157665. 157811. 266141. 162276. 183001. 227631. 414268. 141003. 137581.
#  181023. 238491. 214677. 177183. 225637. 162592. 218226. 262353. 183551.
#  273164. 277817. 214835. 264249. 303718. 250328. 181480. 262930. 170811.
#  199308. 248324. 271327. 297897. 237549. 255171. 506399. 187419. 211350.
#  218880. 308203. 264392. 359470. 159313. 160932. 169415. 140602. 312507.
#  335575. 430098. 193224. 227228. 165060. 164213. 314036. 240714. 236601.
#  255444. 240849. 176106. 210468. 200998. 218390. 291974. 208258. 231530.
#  183368. 108687. 244060. 164078. 245867. 196860. 329331. 167578. 269851.
#  192158. 345652. 254760. 285647. 105461. 172751. 167613. 158284. 175156.
# ...

# %%
Y_test.shape
# Out:
# (360,)

# %%
Y_test = Y_test.reshape((360,1))
Id = np.zeros((360,1))
for i in range(Y_test.shape[0]):
    Id[i]=1101+i

# %%
Id
# Out:
# array([[1101.],
#        [1102.],
#        [1103.],
#        [1104.],
#        [1105.],
#        [1106.],
#        [1107.],
#        [1108.],
#        [1109.],
#        [1110.],
#        [1111.],
#        [1112.],
#        [1113.],
#        [1114.],
#        [1115.],
#        [1116.],
#        [1117.],
#        [1118.],
#        [1119.],
#        [1120.],
#        [1121.],
#        [1122.],
#        [1123.],
#        [1124.],
#        [1125.],
#        [1126.],
#        [1127.],
#        [1128.],
#        [1129.],
#        [1130.],
#        [1131.],
#        [1132.],
#        [1133.],
#        [1134.],
#        [1135.],
#        [1136.],
#        [1137.],
#        [1138.],
#        [1139.],
#        [1140.],
#        [1141.],
#        [1142.],
#        [1143.],
#        [1144.],
#        [1145.],
#        [1146.],
#        [1147.],
#        [1148.],
#        [1149.],
#        [1150.],
#        [1151.],
#        [1152.],
#        [1153.],
#        [1154.],
#        [1155.],
# ...

# %%
Y_test = np.hstack((Id,Y_test))
print(Y_test)
# Out:
# [[  1101.  84473.]
#  [  1102. 163124.]
#  [  1103. 177110.]
#  [  1104. 210943.]
#  [  1105. 155417.]
#  [  1106. 382020.]
#  [  1107. 266964.]
#  [  1108. 302588.]
#  [  1109. 205604.]
#  [  1110. 347220.]
#  [  1111. 228685.]
#  [  1112. 254519.]
#  [  1113. 166899.]
#  [  1114. 183885.]
#  [  1115. 169529.]
#  [  1116. 362163.]
#  [  1117. 252990.]
#  [  1118. 185503.]
#  [  1119. 168959.]
#  [  1120. 172457.]
#  [  1121. 168256.]
#  [  1122. 280488.]
#  [  1123. 116212.]
#  [  1124. 145014.]
#  [  1125. 220128.]
#  [  1126. 168817.]
#  [  1127. 250555.]
#  [  1128. 300743.]
#  [  1129. 274898.]
#  [  1130. 177672.]
#  [  1131. 191587.]
#  [  1132. 163199.]
#  [  1133. 202039.]
#  [  1134. 294212.]
#  [  1135. 221652.]
#  [  1136. 149961.]
#  [  1137. 157665.]
#  [  1138. 157811.]
#  [  1139. 266141.]
#  [  1140. 162276.]
#  [  1141. 183001.]
#  [  1142. 227631.]
#  [  1143. 414268.]
#  [  1144. 141003.]
#  [  1145. 137581.]
#  [  1146. 181023.]
#  [  1147. 238491.]
# ...

# %%
Y_test = pd.DataFrame(Y_test)
Y_test.to_csv('Y_test(housing_prices)3',index = False)

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
GBR = GradientBoostingRegressor(max_depth=5)

# %%
GBR.fit(X,Y)
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#                           learning_rate=0.1, loss='ls', max_depth=5,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_iter_no_change=None, presort='auto',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
y_pred = GBR.predict(X_test_df)

# %%
for i in range(y_pred.shape[0]):
    y_pred[i] = int(y_pred[i])

y_pred = y_pred.reshape((360,1))
Id = np.zeros((360,1))
for i in range(y_pred.shape[0]):
    Id[i]=1101+i

# %%
y_pred = np.hstack((Id,y_pred))
print(y_pred)
# Out:
# [[  1101.  67457.]
#  [  1102. 118090.]
#  [  1103. 130920.]
#  [  1104. 133895.]
#  [  1105.  93779.]
#  [  1106. 291567.]
#  [  1107. 182539.]
#  [  1108. 229754.]
#  [  1109. 159828.]
#  [  1110. 287675.]
#  [  1111. 164938.]
#  [  1112. 182627.]
#  [  1113. 115634.]
#  [  1114. 123721.]
#  [  1115. 120041.]
#  [  1116. 286809.]
#  [  1117. 183991.]
#  [  1118. 130392.]
#  [  1119. 139121.]
#  [  1120. 111162.]
#  [  1121. 111682.]
#  [  1122. 195699.]
#  [  1123.  85081.]
#  [  1124.  92046.]
#  [  1125. 165812.]
#  [  1126. 106953.]
#  [  1127. 176795.]
#  [  1128. 218803.]
#  [  1129. 217446.]
#  [  1130. 112639.]
#  [  1131. 140549.]
#  [  1132. 127793.]
#  [  1133. 124056.]
#  [  1134. 246330.]
#  [  1135. 167251.]
#  [  1136. 102918.]
#  [  1137. 119241.]
#  [  1138.  80555.]
#  [  1139. 178322.]
#  [  1140. 117088.]
#  [  1141. 114835.]
#  [  1142. 167607.]
#  [  1143. 345375.]
#  [  1144. 104088.]
#  [  1145.  87044.]
#  [  1146. 128980.]
#  [  1147. 151828.]
# ...

# %%
y_pred = pd.DataFrame(y_pred)
y_pred.to_csv('Y_test(housing_prices)4',index = False)
